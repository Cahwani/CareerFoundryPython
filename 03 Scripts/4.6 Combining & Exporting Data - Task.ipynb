# %% [markdown]
# # Merging and exporting data

# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path=r'C:\Users\61491\12-2020 Instacart Basket Analysis'

# %%
df_ords_prods_com = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
df_prods=pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %% [markdown]
# ## Checking data

# %%
# Check Dataframe
df_ords_prods_com.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0     94891            4             4                   5                 13
# 1     94891            4             4                   5                 13
# 2     23391            7            17                   0                 10
# 3     23391            7            17                   0                 10
# 4     23391            7            17                   0                 10
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                    15.0       22199                  1          0   both
# 1                    15.0       25146                  2          0   both
# 2                    28.0       13198                  1          1   both
# 3                    28.0       42803                  2          1   both
# 4                    28.0        8277                  3          1   both

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_ords_prods_com.shape
# Out:
# (1048575, 10)

# %%
# Remove unwanted column from combined dataframe
df_ords_prods_com = df_ords_prods_com.drop(columns = ['_merge'])

# %%
# Check  Combined Dataframe
df_ords_prods_com.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0     94891            4             4                   5                 13
# 1     94891            4             4                   5                 13
# 2     23391            7            17                   0                 10
# 3     23391            7            17                   0                 10
# 4     23391            7            17                   0                 10
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                    15.0       22199                  1          0
# 1                    15.0       25146                  2          0
# 2                    28.0       13198                  1          1
# 3                    28.0       42803                  2          1
# 4                    28.0        8277                  3          1

# %%
# Remove unwanted column from products dataframe
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
# Check products dataframe
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# ## Merging DataFrames

# %%
# Merge
df_ords_prods_merged = df_ords_prods_com.merge(df_prods, on = 'product_id', indicator = True)

# %%
df_ords_prods_merged
# Out:
#          order_id  customer_id  order_number  orders_day_of_week  \
# 0           94891            4             4                   5
# 1           31925        47329             4                   3
# 2           94891            4             4                   5
# 3           95113          410             2                   1
# 4          109354          658            14                   0
# ...           ...          ...           ...                 ...
# 1047653     93952       206165            22                   5
# 1047654     93952       206165            22                   5
# 1047655     90035       206166             8                   3
# 1047656     37727       206193            32                   0
# 1047657     28210       206201             1                   6
#
#          order_hour_of_day  days_since_prior_order  product_id  \
# 0                       13                    15.0       22199
# ...

# %%
df_ords_prods_merged['_merge'].value_counts()
# Out:
# both          1047658
# left_only           0
# right_only          0
# Name: _merge, dtype: int64

# %%
df_ords_prods_merged.shape
# Out:
# (1047658, 14)

# %% [markdown]
# ## Exporting DataFrame

# %%
# Exporting as 'csv'
df_ords_prods_merged.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.csv'))
